# %%
from tkinter import Tk, Label, Button, filedialog
from PIL import Image, ImageTk
import cv2
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn import datasets,linear_model,metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn import datasets
import os
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
from tkinter import*
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
main=pd.read_csv(r"C:\Users\ebi\Desktop\hospital.csv")
main.drop_duplicates()
main.drop_duplicates(inplace=True)
main.dropna(inplace=True)
main.reset_index(inplace=True,drop=True)
features = ['age', 'sex', 'cp', 'trtbps','chol','fbs','restecg','thalachh','exng','oldpeak','slp','caa','thall']
x = main[features]
y = main['output']
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)
dtree = DecisionTreeClassifier()
dtree = dtree.fit(X_train, y_train)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
model = LogisticRegression(max_iter=1000 ,random_state=42)
model.fit(X_train_scaled, y_train)
reg =KNeighborsClassifier(n_neighbors=7,metric='manhattan',weights='uniform')
reg.fit(X_train, y_train)
root = Tk()
root.title('ebi')
root.geometry("640x630")
root.config(bg='gray25')
l = Label(root, text='سن :',font=('b nazanin',20,'bold'), bg='gray25', fg='snow')
l.place(x=35, y=20)
o = Label(root, text='جنسیت:',font=('b nazanin',20,'bold'), bg='gray25', fg='snow')
o.place(x=35, y=50)
z = Label(root, text='نوع درد قفسه‌سینه :',font=('b nazanin',20,'bold'), bg='gray25', fg='snow')
z.place(x=35, y=85)
pas = Label(root, text='فشار خون موقع استراحت:',font=('b nazanin',20,'bold'), bg='gray25', fg='snow')
pas.place(x=35, y=120)
pas2 = Label(root, text='کلسترول سرم خون :',font=('b nazanin',20,'bold'), bg='gray25', fg='snow')
pas2.place(x=35, y=150)
pas3 = Label(root, text='قند خون ناشتا  :',font=('b nazanin',20,'bold'), bg='gray25', fg='snow')
pas3.place(x=35, y=180)
pas55 = Label(root, text='نتیجه‌ی نوار قلب موقع استراحت :',font=('b nazanin',20,'bold'), bg='gray25', fg='snow')
pas55.place(x=35, y=210)
pas33 = Label(root, text='بیشترین ضربان قلب ثبت‌شده :',font=('b nazanin',20,'bold'), bg='gray25', fg='snow')
pas33.place(x=35, y=240)
pas44 = Label(root, text='آیا با ورزش درد قفسه‌سینه ایجاد شده :',font=('b nazanin',20,'bold'), bg='gray25', fg='snow')
pas44.place(x=35, y=275)
pas55 = Label(root, text='افت سی تی نسبت به حالت استراحت:',font=('b nazanin',20,'bold'), bg='gray25', fg='snow')
pas55.place(x=35, y=310)
pas66 = Label(root, text='شیب بخش سی تی در ای سی جی:',font=('b nazanin',20,'bold'), bg='gray25', fg='snow')
pas66.place(x=35, y=375)
pas77 = Label(root, text='تعداد رگ‌های اصلی قلب :',font=('b nazanin',20,'bold'), bg='gray25', fg='snow')
pas77.place(x=35, y=410)
pas77 = Label(root, text='نتیجه تست thalassemia یا Thal :',font=('b nazanin',20,'bold'), bg='gray25', fg='snow')
pas77.place(x=35, y=450)

e = Spinbox(root, bd=3, from_=1, to_=110)  
e.place(x=400, y=25)
k = Spinbox(root, bd=3, from_=0, to_=1)
k.place(x=400, y=55)
i = Spinbox(root, bd=3, from_=0, to_=3)
i.place(x=400, y=85)
w = Spinbox(root, bd=3, from_=100, to_=200)
w.place(x=400, y=120)
w3 = Spinbox(root, bd=3, from_=200, to_=400)
w3.place(x=400, y=155)
w4 =Spinbox(root, bd=3, from_=0, to_=1)
w4.place(x=400, y=185)
s = Spinbox(root, bd=3, from_=0, to_=1)
s.place(x=400, y=215)
t = Spinbox(root, bd=3, from_=100, to_=200)
t.place(x=400, y=250)
c = Spinbox(root, bd=3, from_=0, to_=1)
c.place(x=400, y=280)
w5=Scale(root,from_=0,to=10,orient=HORIZONTAL,length=370,font=("Consolas",10,'bold'),tickinterval=20
            ,bg='#7436f7',activebackground='#7436f7',
            resolution=0.1,troughcolor='#69EAFF',
            )
w5.place(x=380, y=310)
w6 =Spinbox(root, bd=3, from_=0, to_=2)
w6.place(x=400, y=380)
w7 =Spinbox(root, bd=3, from_=0, to_=2)
w7.place(x=400, y=413)
w8 =Spinbox(root, bd=3, from_=1, to_=3)
w8.place(x=420, y=450)
u = StringVar()
u.set(None)
def read():
    data1=[int(e.get()),int(k.get()),int(i.get()),int(w.get()),int(w3.get()),int(w4.get()),int(s.get()),int(t.get()),int(c.get()),int(w5.get()),int(w6.get()),int(w7.get()),int(w8.get())]
    df = pd.DataFrame([data1], columns=features)
    p = dtree.predict(df)
    df_scaled = scaler.transform(df)
    p2 = model.predict(df_scaled)
    df_scaled = pd.DataFrame(df_scaled, columns=features)
    p3 = reg.predict(df_scaled)
    z2 = Label(root, text=('tree:',p),font=('b nazanin',20,'bold'), bg='gray25', fg='red')
    z2.place(x=50, y=550)
    z3 = Label(root, text=('Log:',p2),font=('b nazanin',20,'bold'), bg='gray25', fg='red')
    z3.place(x=200, y=550)
    z4 = Label(root, text=('knn:',p3),font=('b nazanin',20,'bold'), bg='gray25', fg='red')
    z4.place(x=350, y=550)
kk = Button(root, width=5, height=3, bg='black', fg='snow', text='check', command=read)
kk.place(x=470, y=500)
root.mainloop()
